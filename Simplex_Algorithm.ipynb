# %%
#To run the code just UPLOAD Simplex EXCEL FILE by pressing on Folder icon[4th]on
#leftside of COLAB Homescreen.

#Coded passionately By Ahmed Harbi.
#Date :13/11/2020 && Time : 3:42AM

# Listz Relates Objective Function Variables' Coeffiecients.
# List1 Relates Functional Constrain No.1 Coeffiecients.
# List2 Relates Functional Constrain No.2 Coeffiecients.
# List3 Relates Functional Constrain No.3 Coeffiecients.
#Typical Form of each [] is [X1,X2,S1,S2,S3,RHS] ' Coefficients.

import pandas as pd 
import numpy as np

X1_C=pd.read_excel('Simplex.xlsx',sheet_name='Sheet1',usecols="A")
X2_C=pd.read_excel('Simplex.xlsx',sheet_name='Sheet1',usecols="D")
RHS_C =pd.read_excel('Simplex.xlsx',sheet_name='Sheet1',usecols="G")



X1_CList = X1_C.values.tolist()
X1_CList = np.array(X1_CList).T
print(X1_CList[0])

    

X2_CList=X2_C.values.tolist()
X2_CList = np.array(X2_CList).T
print(X2_CList[0])

RHS_CList=RHS_C.values.tolist()
RHS_CList = np.array(RHS_CList).T

print(RHS_CList[0])
Listz = [0,0,0,0,0,0]
Listz[0]=(X1_CList[0][3])*-1
Listz[1]=(X2_CList[0][3])*-1
            



List1 = np.array([0,0,0,0,0,0])
List2 = np.array([0,0,0,0,0,0])
List3 = np.array([0,0,0,0,0,0])

for i in range(3): 
    
    if i == 0:
        List1[i]=X1_CList[0][i]
        List2[i]=X1_CList[0][i+1]
        List3[i]=X1_CList[0][i+2]
        
        List1[i+2]=1
        List1[i+5]=RHS_CList[0][i]
        print("list1 in side if",List1)

    elif i==1:
        List1[i]=X2_CList[0][i-1]
        List2[i]=X2_CList[0][i]
        List3[i]=X2_CList[0][i+1]
        
        List2[i+2]=1
        List2[i+4]=RHS_CList[0][i]
    elif i== 2 :
        
        List3[i+2]=1
        List3[i+3]=RHS_CList[0][i]
    else :
        break
        

print("list1",List1)
print("list2",List2)
print("List3",List3)
#List1 = np.array([1,0,1,0,0,4])
#List2 = np.array([0,2,0,1,0,12])
#List3 = np.array([3,2,0,0,1,18])


Dic={1:List1,2:List2,3:List3}
Solution_Dictionary={'X1':0,'X2':0,'Z':0}
for i in range(10):
    
        entering_variable = min(Listz[0:2])
        print("entering_variable",entering_variable)
        entering_variable_index = Listz.index(entering_variable)
        print("entering_variable_index",entering_variable_index)
        RHS_PC_list=[0,0,0]
        for k in range(3):
            arbtirary_list=Dic[k+1]
            RHS_PC = arbtirary_list[-1]/arbtirary_list[entering_variable_index]
            RHS_PC_list[k] =  RHS_PC
        print("RHS_PC_list",RHS_PC_list)
        #Getting minium Value of RHS/PC
        RHS_PC_list_min = min(RHS_PC_list)
        PivotRow_index = RHS_PC_list.index(RHS_PC_list_min)
        print("PivotRow_index",PivotRow_index)
        
        #################################
        if entering_variable_index == 0 :
            
            if PivotRow_index == 0 :
                print("X1 is entering & S1 is Leaving")
                
            elif PivotRow_index == 1 :
                print("X1 is entering & S2 is Leaving")
            else :
                print("X1 is entering & S3 is Leaving")
                
        elif entering_variable_index == 1 :
            
            if PivotRow_index == 0 :
                print("X2 is entering & S1 is Leaving")
            elif PivotRow_index == 1 :
                print("X2 is entering & S2 is Leaving")
            else :
                print("X2 is entering & S3 is Leaving") 

        #################################

        
        
        #pssible values for PivorRow_index is 0,1,2
        #if it was 0 that means First Basic Variable 
        #if it was 1 that means Second Basic Variable
        #if it was 3 that means Third Basic Variable
        unity_Pivot_row_list = [0,0,0,0,0,0]

        if PivotRow_index == 0 :
            for k in range(len(Listz)):
                unity_Pivot_row = Dic[1]/Dic[1][entering_variable_index]

            print(unity_Pivot_row_list)
            Dic[1]=unity_Pivot_row


        elif PivotRow_index == 1 :
            for k in range(len(Listz)):
                unity_Pivot_row = Dic[2]/Dic[2][entering_variable_index]
            Dic[2]=unity_Pivot_row
            print(unity_Pivot_row)
            print(Dic)
        else: 
            for k in range(len(Listz)):
                unity_Pivot_row = Dic[3]/Dic[3][entering_variable_index]
            Dic[3]=unity_Pivot_row


        #########################################        
        #iterating over Dictionary and Obj.Fun.
        #1st Dictionary
        for i in range(3):
            if i == PivotRow_index :
                continue
            else:
                if Dic[i+1][entering_variable_index] == 0:
                    continue
                else:
                     Dic[i+1]=  (Dic[PivotRow_index+1] * -1 *Dic[i+1][entering_variable_index])+Dic[i+1]
                print("Dic[i+1]",Dic[i+1])
                
                    
        #2nd Obj.Fun
        Listz=(Dic[PivotRow_index+1] * -1 *Listz[entering_variable_index])+Listz
        Listz=list(Listz)
        print(Listz)
        
        
        #########################################

        if ((Listz[0]>0 or Listz[0]==0) and  (Listz[1]>0 or Listz[1]==0)):
            break

            
print("Dic",Dic)

for i in range(3):
    for j in range(2):
        if Dic[i+1][j] == 0:
            continue
        elif Dic[i+1][j] == 1:
            if j==0 :
                print("X1")
                Solution_Dictionary['X1']=Dic[i+1][-1]
                
            elif j==1:
                print("X2")
                Solution_Dictionary['X2']=Dic[i+1][-1]

Solution_Dictionary['Z']=Listz[-1]               
print(Solution_Dictionary)
# Out:
# [5 2 5]
# [5 0 5]
# ['11' '20' 'Z']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-29006661d8e4> in <module>()
#      36 print(RHS_CList[0])
#      37 Listz = [0,0,0,0,0,0]
# ---> 38 Listz[0]=(X1_CList[0][3])*-1
#      39 Listz[1]=(X2_CList[0][3])*-1
#      40
#
# IndexError: index 3 is out of bounds for axis 0 with size 3
